# %% [markdown]
# <a href="https://colab.research.google.com/github/alannnn04/Extracci-n-de-Datos/blob/main/Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  #Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Convertir en dataframe
df= pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS **

# %%
#Filtro por objeto
#Variables filtradas: Se filtro la "region" escogiendo "Caribbean"
filtro1=df[df["region"] == "Caribbean"]
filtro1
# Out:
#               code                              name     region  surface_area  \
# continent
# North America  ABW                             Aruba  Caribbean         193.0
# North America  AIA                          Anguilla  Caribbean          96.0
# North America  ANT              Netherlands Antilles  Caribbean         800.0
# North America  ATG               Antigua and Barbuda  Caribbean         442.0
# North America  BHS                           Bahamas  Caribbean       13878.0
# North America  BRB                          Barbados  Caribbean         430.0
# North America  CuB                              Cuba  Caribbean      110861.0
# North America  CYM                    Cayman Islands  Caribbean         264.0
# North America  DMA                          Dominica  Caribbean         751.0
# North America  DOM                Dominican Republic  Caribbean       48511.0
# North America  GLP                        Guadeloupe  Caribbean        1705.0
# ...

# %%
#Filtro por filas
#Variables filtradas: Se filtrarón las filas de la 226 a la 231
filtro2=df.iloc[ 226:232 , : ]
filtro2
# Out:
#               code                              name          region  \
# continent
# North America  VCT  Saint Vincent and the Grenadines       Caribbean
# South America  VEN                         Venezuela   South America
# North America  VGB           Virgin Islands, British       Caribbean
# North America  VIR              Virgin Islands, u.S.       Caribbean
# Asia           VNM                           Vietnam  Southeast Asia
# Oceania        VuT                           Vanuatu       Melanesia
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         388.0             1979.0      114000             72.3
# South America      912050.0             1811.0    24170000             73.1
# North America         151.0                NaN       21000             75.4
# North America         347.0                NaN       93000             78.1
# Asia               331689.0             1945.0    79832000             69.3
# ...

# %%
#Filtro por columnas
#Variables filtradas: Se filtrarón las columnas: 2, 3 y 12
filtro3=df.iloc[ : , [2,3,12]]  #columnas no consecutivas
filtro3
# Out:
#                                   region  surface_area  capital
# continent
# North America                  Caribbean         193.0    129.0
# Asia           Southern and Central Asia      652090.0      1.0
# Africa                    Central Africa     1246700.0     56.0
# North America                  Caribbean          96.0     62.0
# Europe                   Southern Europe       28748.0     34.0
# ...                                  ...           ...      ...
# Asia                         Middle East      527968.0   1780.0
# Europe                   Southern Europe      102173.0   1792.0
# Africa                   Southern Africa     1221037.0    716.0
# Africa                    Eastern Africa      752618.0   3162.0
# Africa                    Eastern Africa      390757.0   4068.0
#
# [239 rows x 3 columns]

# %%
df= pd.read_csv("CountryTable.csv", index_col=2)
df
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
#Variables filtradas: Se filtrarón los continentes(columna 2) "North America"
# y"South America" con su "population"
filtro4=df.loc[["North America","South America"], ["population"]]
filtro4
# Out:
#                population
# continent
# North America      103000
# North America        8000
# North America      217000
# North America       68000
# North America      307000
# North America      241000
# North America       65000
# North America      270000
# North America    31147000
# North America     4023000
# North America    11201000
# North America       38000
# North America       71000
# North America     8495000
# North America      456000
# North America       94000
# North America       56000
# North America    11385000
# North America     6485000
# North America     8222000
# North America     2583000
# North America       38000
# North America      154000
# North America    98881000
# North America       11000
# North America      395000
# North America     5074000
# North America     2856000
# North America     3869000
# North America     6276000
# North America        7000
# North America       17000
# North America     1295000
# North America   278357000
# ...

# %%
#Filtro por cabecera
#Variables filtradas: Imprimimos las primeras 15 filas
filtro5=df.head(15)
filtro5
# Out:
#               code                         name                     region  \
# continent
# North America  ABW                        Aruba                  Caribbean
# Asia           AFG                  Afghanistan  Southern and Central Asia
# Africa         AGO                       Angola             Central Africa
# North America  AIA                     Anguilla                  Caribbean
# Europe         ALB                      Albania            Southern Europe
# Europe         AND                      Andorra            Southern Europe
# North America  ANT         Netherlands Antilles                  Caribbean
# Asia           ARE         united Arab Emirates                Middle East
# South America  ARG                    Argentina              South America
# Asia           ARM                      Armenia                Middle East
# Oceania        ASM               American Samoa                  Polynesia
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
#Variables filtradas: Filtramos los datos que cumplan que en la
# columna "life_expectancy" tengan un valor mayor a 76
filtro6=df[df["life_expectancy"] > 76]
filtro6
# Out:
#               code                       name                     region  \
# continent
# North America  ABW                      Aruba                  Caribbean
# North America  AIA                   Anguilla                  Caribbean
# Europe         AND                    Andorra            Southern Europe
# Oceania        AuS                  Australia  Australia and New Zealand
# Europe         AuT                    Austria             Western Europe
# Europe         BEL                    Belgium             Western Europe
# North America  BMu                    Bermuda              North America
# North America  CAN                     Canada              North America
# Europe         CHE                Switzerland             Western Europe
# North America  CuB                       Cuba                  Caribbean
# North America  CYM             Cayman Islands                  Caribbean
# Asia           CYP                     Cyprus                Middle East
# ...

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
#Variables filtradas: Filtramos los datos que cumplan que en la
# columna "life_expectancy" tengan un valor mayor a 76 y que en la
# columna "region" tengan el dato "Caribbean"
filtro7=df[(df["life_expectancy"] > 76) & (df["region"] == "Caribbean")]
filtro7
# Out:
#               code                  name     region  surface_area  \
# continent
# North America  ABW                 Aruba  Caribbean         193.0
# North America  AIA              Anguilla  Caribbean          96.0
# North America  CuB                  Cuba  Caribbean      110861.0
# North America  CYM        Cayman Islands  Caribbean         264.0
# North America  GLP            Guadeloupe  Caribbean        1705.0
# North America  MSR            Montserrat  Caribbean         102.0
# North America  MTQ            Martinique  Caribbean        1102.0
# North America  VIR  Virgin Islands, u.S.  Caribbean         347.0
#
#                independence_year  population  life_expectancy      gnp  \
# continent
# North America                NaN      103000             78.4    828.0
# North America                NaN        8000             76.1     63.2
# North America             1902.0    11201000             76.2  17843.0
# ...

# %%
#Filtro o
#Variables filtradas: Filtramos los datos que cumplan que en la
# columna "life_expectancy" tengan un valor mayor a 76 o que en la
# columna "region" tengan el dato "Caribbean"
filtro8=df[(df["life_expectancy"] > 76) | (df["region"] == "Caribbean")]
filtro8
# Out:
#               code                              name           region  \
# continent
# North America  ABW                             Aruba        Caribbean
# North America  AIA                          Anguilla        Caribbean
# Europe         AND                           Andorra  Southern Europe
# North America  ANT              Netherlands Antilles        Caribbean
# North America  ATG               Antigua and Barbuda        Caribbean
# ...            ...                               ...              ...
# Asia           TWN                            Taiwan     Eastern Asia
# North America  uSA                     united States    North America
# North America  VCT  Saint Vincent and the Grenadines        Caribbean
# North America  VGB           Virgin Islands, British        Caribbean
# North America  VIR              Virgin Islands, u.S.        Caribbean
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
#Filtro not
#Variables filtradas: Filtramos los datos que cumplan que en la
# columna "life_expectancy" no tengan un valor mayor a 76 y que en la
# columna "region" no tengan el dato "Caribbean"
filtro9=df[~(df["life_expectancy"] >= 76) & ~(df["region"] == "Caribbean")]
filtro9
# Out:
#               code                  name                     region  \
# continent
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# Europe         ALB               Albania            Southern Europe
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# ...            ...                   ...                        ...
# Asia           YEM                 Yemen                Middle East
# Europe         YuG            Yugoslavia            Southern Europe
# Africa         ZAF          South Africa            Southern Africa
# Africa         ZMB                Zambia             Eastern Africa
# Africa         ZWE              Zimbabwe             Eastern Africa
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Filtro9.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files


files.download("Filtro9.csv")
